# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
pd.set_option('display.max_columns', 999)
pd.set_option('display.max_rows', 40)

# %%
with open('noaa_csv_final.pickle','rb') as f:
    df = pickle.load(f)

# %%
# Finding unnecessary columns
titles = []
for title in df.columns:
    if 'ATTRIBUTES' in title:
        titles.append(title)

# %%
df.drop(columns=titles, inplace=True)
# Out:
# ----------------------------------------------------------------------
# KeyError                             Traceback (most recent call last)
# <ipython-input-272-011c80ccfa32> in <module>
# ----> 1 df.drop(columns=titles, inplace=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
df.drop(columns=['HN01', 'HN02', 'HX01', 'HX02', 'LN01', 'LN02', 'LX01', 'LX02',
       'MN02', 'MX02', 'HN03', 'HN04', 'HX03', 'HX04', 'LN03', 'LN04',
       'LX03', 'LX04', 'MN03', 'MN04', 'MX03', 'MX04', 'HN05', 'HN06',
       'HN07', 'HN08', 'HN09', 'HX05', 'HX06', 'HX07', 'HX08', 'LN05',
       'LN06', 'LN07', 'LN08', 'LN09', 'LX05', 'LX06', 'LX07', 'LX08',
       'MN05', 'MN06', 'MN07', 'MN08', 'MN09', 'MX05', 'MX06', 'MX07',
       'MX08','WDF1', 'WDF2', 'WDF5', 'WDFM', 'WSF1', 'WSF2', 'WSF5',
                 'MN01', 'MX01','WSFM','CDSD','CLDD','HDSD','HTDD','WDFG'], inplace=True)

# %%
weather.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.columns.values
# Out:
# array(['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'NAME',
#        'DP01', 'DP10', 'DP1X', 'DSND', 'DSNW', 'DT00', 'DT32', 'DX32',
#        'DX70', 'DX90', 'EMNT', 'EMSD', 'EMSN', 'EMXP', 'EMXT', 'FZF0',
#        'FZF1', 'FZF2', 'FZF3', 'FZF4', 'FZF5', 'FZF6', 'FZF7', 'FZF8',
#        'FZF9', 'PRCP', 'SNOW', 'TAVG', 'TMAX', 'TMIN', 'WSFG', 'county',
#        'state', 'WDMV', 'AWND', 'EVAP', 'PSUN', 'TSUN'], dtype=object)

# %%
weather.columns.values
# Out:
# array(['LATITUDE', 'LONGITUDE', 'ELEVATION', 'precip_num_days_over_0.01',
#        'precip_num_days_over_0.1', 'precip_num_days_over_1',
#        'snow_depth_num_days_over_1', 'snowfall_num_days_over_1',
#        'max_temp_num_days_under_0', 'min_temp_num_days_under_32',
#        'max_temp_num_days_under_32', 'max_temp_num_days_over_70',
#        'max_temp_num_days_over_90', 'min_temp_year',
#        'max_snow_depth_year', 'max_snowfall_year', 'max_precip_day',
#        'max_temp_year', 'first_min_temp_under_32',
#        'first_min_temp_under_28', 'first_min_temp_under_24',
#        'first_min_temp_under_20', 'first_min_temp_under_16',
#        'last_min_temp_under_32', 'last_min_temp_under_28',
#        'last_min_temp_under_24', 'last_min_temp_under_20',
#        'last_min_temp_under_16', 'total_precip_year',
#        'total_snowfall_year', 'avg_temp_year', 'max_temp_year',
#        'min_temp_year'], dtype=object)

# %%
weather.rename(columns={'DP01':'precip_num_days_over_0.01', 'DP10':'precip_num_days_over_0.1','DP1X':'precip_num_days_over_1', 'DSND':'snow_depth_num_days_over_1', 'DSNW':'snowfall_num_days_over_1', 'DT00':'max_temp_num_days_under_0', 'DT32':'min_temp_num_days_under_32', 'DX32':'max_temp_num_days_under_32',
       'DX70':'max_temp_num_days_over_70', 'DX90':'max_temp_num_days_over_90', 'EMNT':'min_temp_year', 'EMSD':'max_snow_depth_year', 'EMSN':'max_snowfall_year', 'EMXP':'max_precip_day', 'EMXT':'max_temp_year', 'FZF0':'first_min_temp_under_32',
       'FZF1':'first_min_temp_under_28', 'FZF2':'first_min_temp_under_24', 'FZF3':'first_min_temp_under_20', 'FZF4':'first_min_temp_under_16', 'FZF5':'last_min_temp_under_32', 'FZF6':'last_min_temp_under_28', 'FZF7':'last_min_temp_under_24', 'FZF8':'last_min_temp_under_20',
       'FZF9':'last_min_temp_under_16', 'PRCP':'total_precip_year', 'SNOW':'total_snowfall_year', 'TAVG':'avg_temp_year', 'TMAX':'max_temp_year', 'TMIN':'min_temp_year'},inplace=True)

# %%
# .loc[:,['state','county','TAVG','PRCP','TMAX','TMIN']]
weather = df.groupby(['state','county','DATE']).mean()

# %%
# weather.drop(columns=['Unnamed: 0'], inplace=True)

# %%
weather.drop(columns=['PSUN','TSUN','EVAP','WSFG', 'WDMV', 'AWND'], inplace=True)

# %%
l=[]
for column in weather:
    if len(weather[weather.loc[:,column].isnull()]) >  len(weather)/3:
        l.append(column)

# %%
l
# Out:
# ['DSND', 'DSNW', 'EMSD', 'EMSN', 'FZF3', 'FZF4', 'SNOW']

# %%
weather[weather.DP01.isnull()]
# Out:
#                state           county  DATE   LATITUDE  LONGITUDE   ELEVATION  \
# 11           Alabama   Barbour County  2010  31.911145 -85.289495  130.150000
# 12           Alabama   Barbour County  2011  31.911145 -85.289495  130.150000
# 14           Alabama   Barbour County  2013  31.952343 -85.350983  128.633333
# 15           Alabama   Barbour County  2014  31.911145 -85.289495  130.150000
# 18           Alabama   Barbour County  2017  31.951390 -85.128890   86.900000
# 45           Alabama    Butler County  2013  31.790100 -86.608700  104.200000
# 47           Alabama    Butler County  2015  31.790100 -86.608700  104.200000
# 65           Alabama  Cherokee County  2010  34.150000 -85.684600  182.900000
# 88           Alabama      Clay County  2012  33.294100 -85.778800  311.500000
# 89           Alabama      Clay County  2013  33.294100 -85.778800  311.500000
# ...              ...              ...   ...        ...        ...         ...
# ...

# %%
weather.ELEVATION.mean()
# Out:
# 443.6183094805869

# %%
# null_to_zero
['DSND','DSNW','PRCP']
# Out:
# ['DSND', 'DSNW', 'DT00', 'DT32', 'DX32', 'DX90']

# %%
#  sketchy zer0
['DT00','DT32','DX32','DX90']

# %%
weather
# Out:
#                                LATITUDE   LONGITUDE    ELEVATION        DP01  \
# state   county          DATE
# Alabama Autauga County  2010  32.482500  -86.485400   100.300000  120.000000
#                         2013  32.825200  -86.416400   107.300000   91.000000
#                         2014  32.653850  -86.450900   103.800000  106.000000
#         Baldwin County  2010  30.521877  -87.796877    31.723077  111.090909
#                         2011  30.516725  -87.801650    29.991667   95.300000
#                         2012  30.503264  -87.798864    27.381818  116.200000
#                         2013  30.574450  -87.787580    38.130000  132.571429
#                         2014  30.554153  -87.800580    35.760000  115.923077
#                         2015  30.542950  -87.763483    33.100000  117.400000
#                         2016  30.519477  -87.744623    27.646154  106.083333
#                         2017  30.584375  -87.776492    37.158333  119.545455
# ...

# %%
# Percentage of null values
weather.isnull().sum()/len(weather)*100
# Out:
# state         0.000000
# county        0.000000
# DATE          0.000000
# LATITUDE      0.000000
# LONGITUDE     0.000000
# ELEVATION     0.022499
# DP01          4.567340
# DP10          4.567340
# DP1X          4.571840
# DSND         42.631508
# DSNW         40.615578
# DT00         17.436890
# DT32         17.436890
# DX32         16.766413
# DX70         16.766413
# DX90         16.766413
# EMNT         17.436890
# EMSD         42.631508
# EMSN         40.615578
# EMXP          4.567340
# EMXT         16.766413
# FZF0         19.047833
# FZF1         21.270756
# FZF2         26.432075
# FZF3         33.690321
# FZF4         42.465014
# FZF5         18.183864
# FZF6         19.425820
# FZF7         21.662242
# FZF8         25.320614
# FZF9         30.643927
# PRCP          3.820366
# SNOW         40.611079
# TAVG         17.873374
# TMAX         16.766413
# TMIN         17.436890
# dtype: float64

# %%
state_names = ['Alabama','Alaska','Arizona','Arkansas','California','Colorado',
  'Connecticut','Delaware','Florida','Georgia','Hawaii','Idaho','Illinois',
  'Indiana','Iowa','Kansas','Kentucky','Louisiana','Maine','Maryland',
  'Massachusetts','Michigan','Minnesota','Mississippi','Missouri','Montana',
  'Nebraska','Nevada','New Hampshire','New Jersey','New Mexico','New York',
  'North Carolina','North Dakota','Ohio','Oklahoma','Oregon','Pennsylvania',
  'Rhode Island','South Carolina','South Dakota','Tennessee','Texas','Utah',
  'Vermont','Virginia','Washington','West Virginia','Wisconsin','Wyoming']

# %%
nan_columns =['ELEVATION',
       'precip_num_days_over_0.01', 'precip_num_days_over_0.1',
       'precip_num_days_over_1', 'snow_depth_num_days_over_1',
       'snowfall_num_days_over_1', 'max_temp_num_days_under_0',
       'min_temp_num_days_under_32', 'max_temp_num_days_under_32',
       'max_temp_num_days_over_70', 'max_temp_num_days_over_90',
       'min_temp_year', 'max_snow_depth_year', 'max_snowfall_year',
       'max_precip_day', 'max_temp_year', 'first_min_temp_under_32',
       'first_min_temp_under_28', 'first_min_temp_under_24',
       'first_min_temp_under_20', 'first_min_temp_under_16',
       'last_min_temp_under_32', 'last_min_temp_under_28',
       'last_min_temp_under_24', 'last_min_temp_under_20',
       'last_min_temp_under_16', 'total_precip_year',
       'total_snowfall_year', 'avg_temp_year', 'max_temp_year',
       'min_temp_year']

# %%
state_weather_df = weather.groupby('state').mean()

# %%
state_weather_df
# Out:
#                    LATITUDE   LONGITUDE    ELEVATION        DP01        DP10  \
# state
# Alabama           32.935625  -86.708194   147.120703  106.804950   75.754375
# Alaska            60.403290 -148.132709   195.689068  160.025573  103.616091
# Arizona           33.600573 -111.413475  1248.987377   48.245330   30.208149
# Arkansas          34.949443  -92.449520   150.430692   95.102416   67.788477
# California        37.816471 -120.791788   589.744270   63.221610   40.942868
# Colorado          38.952330 -105.491926  2118.971008   89.113433   57.855648
# Connecticut       41.631235  -72.641189   107.801589  123.357487   74.633739
# Delaware          39.154195  -75.544826    39.290033  119.918903   76.253175
# Florida           28.861568  -82.573442    20.723028  117.127170   76.396423
# Georgia           32.907052  -83.524914   188.524503  107.520879   73.126743
# Hawaii            21.001636 -157.373271   300.285261  169.923701   85.175260
# ...

# %%
weather_copy = weather.copy()

# %%
weather_copy.loc['Alabama','ELEVATION']
# Out:
# state
# Alabama    100.300000
# Alabama    107.300000
# Alabama    103.800000
# Alabama     31.723077
# Alabama     29.991667
# Alabama     27.381818
# Alabama     38.130000
# Alabama     35.760000
# Alabama     33.100000
# Alabama     27.646154
# Alabama     37.158333
# Alabama    130.150000
# Alabama    130.150000
# Alabama    130.150000
# Alabama    128.633333
# Alabama    130.150000
# Alabama    130.150000
# Alabama    130.150000
# Alabama     86.900000
# Alabama    121.200000
#               ...
# Alabama     50.450000
# Alabama     50.450000
# Alabama     50.450000
# Alabama     50.450000
# Alabama     86.900000
# Alabama     57.950000
# Alabama     65.266667
# Alabama     65.266667
# Alabama     80.350000
# Alabama     80.350000
# Alabama     80.350000
# Alabama     80.350000
# Alabama    257.866667
# Alabama    257.866667
# Alabama    262.750000
# Alabama    257.866667
# Alabama    257.866667
# Alabama    257.866667
# Alabama    262.750000
# Alabama    245.100000
# ...

# %%
for column in nan_columns:
    temp = weather_copy.loc[:,['state',column]]
    for row in temp.iterrows():
        value = state_weather_df.loc[row[1][0],column]
# Out:
#          state    ELEVATION
# 0      Alabama   100.300000
# 1      Alabama   107.300000
# 2      Alabama   103.800000
# 3      Alabama    31.723077
# 4      Alabama    29.991667
# 5      Alabama    27.381818
# 6      Alabama    38.130000
# 7      Alabama    35.760000
# 8      Alabama    33.100000
# 9      Alabama    27.646154
# 10     Alabama    37.158333
# 11     Alabama   130.150000
# 12     Alabama   130.150000
# 13     Alabama   130.150000
# 14     Alabama   128.633333
# 15     Alabama   130.150000
# 16     Alabama   130.150000
# 17     Alabama   130.150000
# 18     Alabama    86.900000
# 19     Alabama   121.200000
# ...        ...          ...
# 22203  Wyoming  2637.046667
# 22204  Wyoming  2677.364286
# 22205  Wyoming  2665.250000
# 22206  Wyoming  2571.187500
# 22207  Wyoming  1541.200000
# 22208  Wyoming  1586.328571
# 22209  Wyoming  1541.200000
# 22210  Wyoming  1541.200000
# 22211  Wyoming  1510.033333
# 22212  Wyoming  1519.844444
# 22213  Wyoming  1541.200000
# ...

# %%
state_weather_df.loc[x[1][0],'ELEVATION']
# Out:
# ----------------------------------------------------------------------
# TypeError                            Traceback (most recent call last)
# <ipython-input-316-e4c32c24967a> in <module>
#       1
# ----> 2 state_weather_df.loc[x[1][0],'ELEVATION']
#
# TypeError: 'generator' object is not subscriptable

# %%
for row in weather_copy.iterrows():
#     value = state_weather_df.loc[row[1][0],column]
#     weather_copy[]
    print(row[1][0])
# row[1]['ELEVATION']
# Out:
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# Alabama
# ...

# %%
weather_copy = weather_copy.reset_index().set_index('state')

# %%
weather_copy
# Out:
#          index           county  DATE   LATITUDE   LONGITUDE    ELEVATION  \
# state
# Alabama      0   Autauga County  2010  32.482500  -86.485400   100.300000
# Alabama      1   Autauga County  2013  32.825200  -86.416400   107.300000
# Alabama      2   Autauga County  2014  32.653850  -86.450900   103.800000
# Alabama      3   Baldwin County  2010  30.521877  -87.796877    31.723077
# Alabama      4   Baldwin County  2011  30.516725  -87.801650    29.991667
# Alabama      5   Baldwin County  2012  30.503264  -87.798864    27.381818
# Alabama      6   Baldwin County  2013  30.574450  -87.787580    38.130000
# Alabama      7   Baldwin County  2014  30.554153  -87.800580    35.760000
# Alabama      8   Baldwin County  2015  30.542950  -87.763483    33.100000
# Alabama      9   Baldwin County  2016  30.519477  -87.744623    27.646154
# Alabama     10   Baldwin County  2017  30.584375  -87.776492    37.158333
# Alabama     11   Barbour County  2010  31.911145  -85.289495   130.150000
# ...

# %% [markdown]
# ### To do list
# - write a function to find a mean of each state/county and then
# -

# %%
weather.iloc[22203]
# Out:
# state             Wyoming
# county       Uinta County
# DATE                 2014
# LATITUDE          40.9802
# LONGITUDE        -110.588
# ELEVATION         2637.05
# DP01              102.364
# DP10              98.0909
# DP1X              2.09091
# DSND              170.091
# DSNW                  NaN
# DT00              24.5714
# DT32              232.214
# DX32              46.5714
# DX70              48.4286
# DX90             0.214286
# EMNT               -29.85
# EMSD              1078.45
# EMSN                  NaN
# EMXP              38.4455
# EMXT                   27
# FZF0             -1.00714
# FZF1             -3.32143
# FZF2             -5.98571
# FZF3             -8.17857
# FZF4               -10.45
# FZF5             -1.42143
# FZF6             -3.67143
# FZF7             -6.07857
# FZF8             -9.48571
# FZF9             -11.2643
# PRCP              669.727
# SNOW                  NaN
# TAVG              3.28071
# TMAX              10.3757
# ...

# %%
weather_copy.head()
# Out:
#                  county  DATE   LATITUDE  LONGITUDE   ELEVATION        DP01  \
# state
# Alabama  Autauga County  2010  32.482500 -86.485400  100.300000  120.000000
# Alabama  Autauga County  2013  32.825200 -86.416400  107.300000   91.000000
# Alabama  Autauga County  2014  32.653850 -86.450900  103.800000  106.000000
# Alabama  Baldwin County  2010  30.521877 -87.796877   31.723077  111.090909
# Alabama  Baldwin County  2011  30.516725 -87.801650   29.991667   95.300000
#
#               DP10  DP1X  DSND  DSNW  DT00       DT32  DX32   DX70   DX90  \
# state
# Alabama  62.000000  14.0   NaN   NaN   NaN        NaN   NaN    NaN    NaN
# Alabama  74.000000  20.0   NaN   NaN   NaN        NaN   NaN    NaN    NaN
# Alabama  74.500000  16.5   NaN   NaN   NaN        NaN   NaN    NaN    NaN
# Alabama  75.909091  21.0   0.0   0.0   0.0  47.200000   0.0  253.0  95.00
# Alabama  64.500000  14.1   NaN   NaN   0.0  21.666667   0.0  280.0  97.25
#
# ...

# %%
# with open('target_variable.pickle','rb') as f:
#     target = pickle.load(f)

# %%
target
# Out:
#                   CTYNAME  year  incidence_rate
# 0          Autauga County  2010        0.000000
# 1          Baldwin County  2010        0.000000
# 2          Barbour County  2010        0.000000
# 3             Bibb County  2010        0.000000
# 4           Blount County  2010        0.000000
# 5          Bullock County  2010        0.000000
# 6           Butler County  2010        0.000000
# 7          Calhoun County  2010        0.000000
# 8         Chambers County  2010        0.000000
# 9         Cherokee County  2010        0.000000
# 10         Chilton County  2010        0.000000
# 11         Choctaw County  2010        0.000000
# 12          Clarke County  2010        0.000000
# 13            Clay County  2010        0.000000
# 14        Cleburne County  2010        0.000000
# 15          Coffee County  2010        0.000020
# 16         Colbert County  2010        0.000000
# 17         Conecuh County  2010        0.000000
# 18           Coosa County  2010        0.000000
# ...
